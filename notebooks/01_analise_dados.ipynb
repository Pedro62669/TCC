# %%
# %pip install matplotlib pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.62.1-cp312-cp312-win_amd64.whl.metadata (119 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl (9.7 MB)
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
# ...

# %%
import os
import matplotlib.pyplot as plt

# Caminho simulado (ajustaremos quando você baixar o dataset real)
caminho_dataset = "../data/raw/AML-Cytomorphology/"

# Simulando a volumetria de dados reais de leucemia vs saudáveis
pastas = {'Saudáveis (Controles)': 1200, 'Leucemia (AML)': 4500} 

cores = ['#2ecc71', '#e74c3c']
explode = (0.1, 0)  # Destaca a fatia das células saudáveis para ênfase

plt.figure(figsize=(8, 6))
plt.pie(pastas.values(), labels=pastas.keys(), autopct='%1.1f%%', 
        startangle=140, colors=cores, explode=explode, shadow=True)

plt.title('Desafio de Engenharia: Desequilíbrio de Classes (AML)', fontsize=14, fontweight='bold')
plt.show()

print("Status: Ambiente Python e bibliotecas gráficas rodando 100% no Cursor!")
# Out:
# Status: Ambiente Python e bibliotecas gráficas rodando 100% no Cursor!
